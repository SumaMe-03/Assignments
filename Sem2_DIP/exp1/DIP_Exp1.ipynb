# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/Fig0314(a)(100-dollars).tif",1)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1192x500>

# %%
arr = np.array(img)

# %%
arr.shape
# Out:
# (500, 1192, 3)

# %%
np.shape(img)
# Out:
# (500, 1192, 3)

# %%
img_resize = cv2.resize(img,(500,500))

cv2_imshow(img_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
img_rotated = cv2.rotate(img_resize,cv2.ROTATE_90_CLOCKWISE)

cv2_imshow(img_rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

cv2_imshow(cv2.resize(img_gray,(200,200)))
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
img3 = cv2.imread("/content/boat2.jpg",1)

img3 = cv2.resize(img3,(400,400))
img = cv2.resize(img,(400,400))
img3 = cv2.add(img3,img)
img3_resize = cv2.resize(img3,(400,400))

cv2_imshow(img3_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
ret, thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

# %%
import matplotlib.pyplot as plt
import numpy as np

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
plt.subplot(121), plt.imshow(img,'gray')
plt.subplot(122), plt.plot(hist)
# Out:
# (<Axes: >, [<matplotlib.lines.Line2D at 0x7c00c41580d0>])

# %%
plt.hist(img.ravel(),256,[0,256]);
plt.show()

# %%
# create a mask
mask = np.zeros(img.shape[:2], np.uint8)
mask[50:300, 25:350] = 255
masked_img = cv2.bitwise_and(img,img,mask = mask)
# Calculate histogram with mask and without mask
# Check third argument for mask
hist_full = cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img],[0],mask,[256],[0,256])
plt.subplot(221), plt.imshow(img, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])
plt.show()

# %%
mean = 0
stddev = 180
noise = np.zeros(img.shape, np.uint8)
noise = cv2.randn(noise, mean, stddev)

# Add noise to image
noisy_img = cv2.add(img, noise)

# %%
cv2_imshow(noisy_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
# Generate random Gaussian noise
mean = 0
stddev = 180
img = cv2.resize(img, (200,200))
noise = np.zeros(img.shape, np.uint8)
noise = cv2.randn(noise, mean, stddev)

# Add noise to image
noise_img = cv2.add(img, noise)

# %%
cv2_imshow(noise_img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
